# %% [markdown]
# ### 5.2

# %%
from pathlib import Path
import os
import numpy as np


tilde_path = os.path.expanduser('~')
subdirectory = 'PROGNUM-repo'
subsub = "Task5"
filename = input({"Enter the file name: "})

OSpath = f"{tilde_path}/{subdirectory}/{subsub}/{filename}"

data = np.loadtxt(OSpath, comments="#",unpack=True)
#firstcol = data[:,0]; secondcol = data[:,1]
print(data[0], data[1])
        
print(f"first column: {firstcol}")
print(f"second column:{secondcol}")
# Out:
# {'Enter the file name: '}numbers
# [ 1.  5. -4. 41.  2.  1.  9. 12. 14.  5.] [ 3. 21.  3.  2. -3.  9. 31.  1. 21. 65.]
# first column: [ 1.  5. -4. 41.  2.  1.  9. 12. 14.  5.]
# second column:[ 3. 21.  3.  2. -3.  9. 31.  1. 21. 65.]

# %% [markdown]
# ### 5.6

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
np.concatenate((a, b))

#makes 1d array
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
import numpy as np

a = np.array([[1, 2], [3, 4]])
b = np.array([[5, 6], [7, 8]])


np.concatenate((a, b), axis=1) 

#axis = 0 stacks rows
#axis = 1 stacks columns
# Out:
# array([[1, 2, 5, 6],
#        [3, 4, 7, 8]])

# %% [markdown]
# ### 5.9

# %%
from imageio.v2 import imwrite, imread
from matplotlib.pyplot import figure, show
from matplotlib.pyplot import cm
import numpy as np
cmaps = sorted(m for m in cm.datad if not m.endswith("_r"))

fig = figure(figsize=(8,8))
frame = fig.add_subplot(1,2,1)
m101 = imread("~/PROGNUM-repo/Task5/m101BW.jpg")
print(m101.shape)
pic = frame.imshow(m101, cmap='jet')
frame.contour(m101, levels=np.percentile(m101, [90,95,99]), colors=['y', 'b', 'r'])

threshold = np.percentile(m101,90)
print(threshold)
m101_filter = np.where(m101>threshold, m101, threshold)
frame = fig.add_subplot(1,2,2)
frame.imshow(m101_filter, cmap='jet')
show()

show()
# Out:
# (568, 620)
# 60.0

# %% [markdown]
# ### 5.10

# %%
from pathlib import Path
import os
import numpy as np
import matplotlib.pyplot as plt

path = Path(f"ngc6946.txt")
data = np.loadtxt(path, comments="#")
#(y,z,x) for python shape, real life it's (x,y,z)
data.shape = (40,50,70)

profile = data[:,25,35]
print(profile)
#max, min, sum, mean, standard deviation
_max = np.max(profile)
_min = np.min(profile)
_sum = np.sum(profile)
mean = np.mean(profile)
std = np.std(profile)

plt.text(0,0.02,f"max={_max:.2f} \n min ={_min:.2f} \n sum = {_sum:.2f} \n mean={mean:.2f} \n standard deviation = {std:.2f}")
plt.plot(profile)



plt.show()
# Out:
# [0.00482 0.00666 0.00705 0.00889 0.01269 0.02012 0.02789 0.03712 0.03985
#  0.04617 0.0606  0.04935 0.02734 0.01746 0.0149  0.0247  0.03478 0.03472
#  0.03174 0.02931 0.02995 0.02909 0.02687 0.0247  0.02483 0.02504 0.02486
#  0.0228  0.01888 0.01625 0.01589 0.01473 0.01294 0.01236 0.01144 0.01118
#  0.01038 0.00848 0.00751 0.0072 ]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 22
#      20 plt.text(0,0.02,f"max={_max:.2f} \n min ={_min:.2f} \n sum = {_sum:.2f} \n mean={mean:.2f} \n standard deviation = {std:.2f}")
#      21 plt.plot(profile)
# ---> 22 plt.clabel(contour, inline=True)
#      25 plt.show()
#
# NameError: name 'contour' is not defined

# %% [markdown]
# ### 5.11

# %%
from pathlib import Path
import os
import numpy as np
from matplotlib.pyplot import figure, show
import matplotlib.pyplot as plt

path = Path(f"ngc6946.txt")
data = np.loadtxt(path, comments="#")
#(y,z,x) for python shape, real life it's (x,y,z)
data.shape = (40,50,70)

profile = data[0,:,:]

mean = np.mean(profile)
std = np.std(profile)
plt.imshow(profile,origin='lower')
contour =plt.contour(profile, levels=[mean,mean+std,mean+2*std], colors=['w', 'b', 'r'])
print(mean,std)
plt.show()
print(profile)
# Out:
# 0.0023294400000000003 0.011558023779452956
# [[-1.42e-03 -1.55e-03 -1.00e-03 ...  7.00e-05  1.00e-04  3.80e-04]
#  [-1.30e-03 -1.62e-03 -1.23e-03 ...  8.00e-05  1.50e-04  6.00e-04]
#  [-1.32e-03 -1.78e-03 -1.70e-03 ...  2.10e-04  2.00e-04  5.50e-04]
#  ...
#  [ 1.80e-04  7.60e-04  1.04e-03 ...  2.90e-04  8.50e-04  5.80e-04]
#  [ 4.00e-05  4.00e-04  5.00e-04 ...  1.15e-03  1.66e-03  1.10e-03]
#  [ 3.90e-04  5.80e-04  5.80e-04 ...  1.69e-03  1.85e-03  1.05e-03]]

# %% [markdown]
# ### 5.12

# %%
from scipy.constants import c
class Galaxy:    
    
    
    """Class for redshift calculation of galaxies"""  
        
    caH_0 = 3968.5      # Calcium H line in rest frame
    
    def __init__(self, name, calciumHline=caH_0):
        self.name = name
        self.caH = calciumHline
        self.lightspeed = c
    def redshift(self):        
        z = (self.caH - self.caH_0)/self.caH
        return z
    def velocitymethod(self):
        z = self.redshift() #calls z from redshift method
        vel = self.lightspeed*z
        return vel

#initializes name and calciumHline
gal1 = Galaxy("NGC1357")
gal2 = Galaxy("NGC1832", 3994.7)

print(gal2.velocitymethod()/1000) #calls velocitymethod() for galxy2
# Out:
# 1966.2458756852695

# %% [markdown]
# ### 5.13

# %%
import numpy as np
from matplotlib.pyplot import show, figure
from matplotlib.patches import Ellipse
Nx = 400
Ny = 300
data = np.random.random((Ny,Nx))

class AstroEllipse(Ellipse):
   def __init__(self, xc, yc, semi_major, semi_minor, position_angle, **args):
     
      assert(semi_major >= semi_minor)  # Prerequisite to make angle unambiguous
      XY = (xc, yc)                  # MPL requires center as a tuple
      angle_mpl = position_angle     # Angle for MatPlotLib's ellipse patch
      height = 2.0*semi_major        # height: is along vertical axis for an unrotated ellipse
      width  = 2.0*semi_minor        # width:  is along horizontal axis for an unrotated ellipse
      super().__init__(XY, width, height, angle=angle_mpl, **args) ## returns these values, in matplotlib's format

fig = figure()
frame = fig.add_subplot(1,1,1,aspect =1)
frame.imshow(data,interpolation='none', origin="lower", cmap='gray')

xc = Nx/2
yc = Ny/2
semimaj = 100
semimin = 50
ang = 30.0
ellipse = AstroEllipse(xc,yc,semimaj,semimin,ang,fill=True,alpha = 0.8)
frame.add_patch(ellipse)
show()
