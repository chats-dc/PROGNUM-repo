# %% [markdown]
# Answers for Week 1
#
# * Name: Diya Chatani
# * Username: dchatani
# * Student s-number: S5882273
# * Group: AS2

# %%
x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Procesed on Jupyter Hub

# %%
x=6
x*=5
x*=4
x*=3
x*=2
print(x)
# Out:
# 720

# %%
import scipy.constants
from scipy.constants import h,c

frequency = 2.42e28
energy = h*frequency
print ('energy=',energy)
# Out:
# energy= 1.6035089763e-05

# %%
import scipy.constants
from scipy.constants import G

mass1=7.342e22
mass2=5.9722e24
r=385000600

f=G*mass1*mass2/(r**2)

print("F=",f)
# Out:
# F= 1.974384051807571e+20

# %% [markdown]
# ![tutorial2.png](attachment:tutorial2.png)

# %% [markdown]
# ![tutorial21.png](attachment:tutorial21.png)

# %% [markdown]
# the dot does not matter in this case because we are checking the tree for the whole directory. If we want to see the tree for a specific directory then we can do:   tree -d ./PROGNUM

# %% [markdown]
# 1.12 screenshot:![tut1-12.png](attachment:tut1-12.png)

# %% [markdown]
# copying directories recursively = cp -r

# %% [markdown]
# ##### Question 1.15
# The Unix command pwd prints the working directory, so it displays the location of the directory you're in.
# In this case, it is: /Users/users/vogelman/Downloads
#
# . refers to Downloads and .. refers to vogelman

# %% [markdown]
# ##### Question 1.16
# cd ~/Desktop

# %% [markdown]
# ##### Question 1.19
# The wildcard * refers to the characters before it. So hi* refers to the characters "hi"
# 1. the command returned files containing numbers from 0-9 and either .c or .o
# 2. the square brackets mean "containing these characters"
# 3. .co with no square brackets only shows the files with the numbers and .co. The one with square brackets shows those with .c or .o
