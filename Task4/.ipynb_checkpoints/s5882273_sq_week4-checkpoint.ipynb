# %% [markdown]
# ### 4.1

# %%
import numpy as np

xysum = []

for i,j in zip([1,2,3,10],[10, 20, 30, 40]):
    xysum.append(i+j)

print(xysum)
# Out:
# [11, 22, 33, 50]

# %%
print([x+y for x,y in zip([1,2,3,10],[10, 20, 30, 40])])
# Out:
# [11, 22, 33, 50]

# %% [markdown]
# ### 4.3

# %%
import numpy as np
game = ["R","P","S"]
rng = np.random.default_rng()
comp =rng.choice(game,1)[0]


player = input("Please enter 'R', 'P', or 'S' (uppercase):")[0]  #only takes in first character

if player== "S" or player=="R" or player=="P":
    if player == comp:
        result ="tie"
    elif player == "S":
        if comp == "R":
            result = "lose"
        else:
            result = "win"
    elif player == "R":
        if comp == "S":
            result = "win"
        else:
            result = "lose" 
    else:
        if comp == "R":
            result = "win"
        else:
            result = "lose"    
    print("Computer plays:"+comp) 

    print("You "+result+"!")
    
else: 

    print("Please try again with the correct input")
# Out:
# Please enter 'R', 'P', or 'S' (uppercase):R
# Computer plays:S
# You win!

# %% [markdown]
# ### 4.4

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm as normal

norm = np.random.normal(loc=185,scale=8,size=100000)


plt.hist(norm,range=[min(norm),max(norm)],bins=40,label="people")


mean = np.mean(norm)
deviation =np.std(norm)
plt.axvline(mean,color='red',label=f'mean={mean:.2f}',linewidth=0.5)
plt.plot([],label=f'standard deviation \n {deviation:.2f}')
#plt.fill_betweenx(norm,mean,mean+deviation,color="orange",alpha=1)
plt.axvspan(mean,mean+deviation,color="orange",alpha=0.5) #used this video: https://www.youtube.com/watch?v=NfjMtTM9Ip0
plt.legend()
plt.show()

h=185 #can also be a value inputted
cdf = normal.cdf(h,scale=deviation,loc=mean)

#within 1 standard deviation:
cdfmin = normal.cdf(h-deviation,scale=deviation,loc=mean)
cdfmax = normal.cdf(h+deviation,scale=deviation,loc=mean)
cdfrange = cdfmax-cdfmin

print(f"probability of people shorter than {h} is: {cdf*100:.2f} percent")
print(f"Probability of people within a deviation of {h} is: {cdfrange*100:.2f}")
# Out:
# probability of people shorter than 185 is: 49.88 percent
# Probability of people within a deviation of 185 is: 68.27

# %% [markdown]
# ### 4.6

# %%
import scipy.integrate as integ

func=input("Enter a function with symbols: ")
anum = input("Enter lower bound: ")
bnum = input("Enter upper bound: ")
a = float(anum)
b = float(bnum)


from sympy import *
init_printing(use_unicode=False)
x = Symbol('x')
answer = integrate(func, (x,a,b))

print(f"The definite integral is: {answer}")
# Out:
# Enter a function with symbols: 2*x
# Enter lower bound: 1
# Enter upper bound: 2
# The definite integral is: 3.00000000000000

# %% [markdown]
# ##
